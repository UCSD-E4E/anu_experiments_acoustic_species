# %%
# imports
from pyha_analyzer import extractors
from pyha_analyzer.preprocessors import MelSpectrogramPreprocessorsNew
import torch
from datetime import datetime


import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader


from torchvision.utils import make_grid

from tqdm.notebook import tqdm

import numpy as np

import matplotlib.pyplot as plt
# Out:
# Traceback (most recent call last):
#
#   File ~/acoustic/anu_experiments_acoustic_species/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     from pyha_analyzer import extractors
#
#   File ~/acoustic/anu_experiments_acoustic_species/.venv/lib/python3.11/site-packages/pyha_analyzer/extractors/__init__.py:5
#     from .musicExtractor import Music as Music
#
#   File ~/acoustic/anu_experiments_acoustic_species/.venv/lib/python3.11/site-packages/pyha_analyzer/extractors/musicExtractor.py:35
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %%
config = {
    "learning_rate": 10e-3,
    "learning_rate_decay": 0.001,
    "device": 'cuda',
    "latent_dim": 10
}

# %%
# extract our data
music_extractor = extractors.Music()
music_ads = music_extractor('/home/a.jajodia.229/acoustic/local_data/muha')

preprocessor = MelSpectrogramPreprocessorsNew(duration=5)
music_ads["train"].set_transform(preprocessor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # extract our data
#       2 music_extractor = extractors.Music()
# ----> 3 music_ads = music_extractor('/home/a.jajodia.229/acoustic/local_data/muha')
#       5 preprocessor = MelSpectrogramPreprocessorsNew(duration=5)
#       6 music_ads["train"].set_transform(preprocessor)
#
# File ~/acoustic/anu_experiments_acoustic_species/.venv/lib/python3.11/site-packages/pyha_analyzer/extractors/musicExtractor.py:60, in Music.__call__(self, audio_path)
#      57 # splitArray = str(curr_wav).split("/")
#      58 # label = splitArray[6]
#      59 label=0
# ---> 60 curr_data = extract_features(curr_wav, label)
#      61 #ignore all corrupt files, as determined by an inability to open them and get their sampling rate
#      62 if curr_data is not None:
#
# File ~/acoustic/anu_experiments_acoustic_species/.venv/lib/python3.11/site-packages/pyha_analyzer/extractors/musicExtractor.py:31, in extract_features(wav, label)
#      21     oneHotEncodedLabel = [1,0]
#      22 # elif label =='LA_Sand_Forrest_ULTRASONIC_03-05-25':
#      23 #     oneHotEncodedLabel = [0,1,0,0]
#      24 # elif label =='A Zoom F3_03-05-25':
#    (...)     28 # else: #invalid label so return nothing
#      29 #     return
# ---> 31 sample_rate, length = get_wav_sampling_rate_length(wav)
#      32 #This means file is likely corrupted
#      33 if (sample_rate==None):
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# architecture from https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0283396
encoder = lambda nfeat : torch.nn.Sequential(
    nn.Conv2d(1, 32, 3, stride=2, bias=False, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(True),
    nn.Conv2d(32, 64, 3, stride=2, bias=False, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    nn.Conv2d(64, 128, 3, stride=2, bias=False, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    nn.Conv2d(128, 256, 3, stride=2, bias=False, padding=1),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    nn.Conv2d(256, 1, 3, stride=2, padding=1),
    nn.Flatten(2),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(nfeat)
)

decoder = lambda nfeat : torch.nn.Sequential(
    nn.Linear(nfeat, 64),
    nn.ReLU
    nn.Linear(64, 64),
    nn.Unflatten(2, (8,8)),
    nn.ReLU(True),
    nn.Upsample(scale_factor=2),
    nn.Conv2d(1, 256, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    nn.Conv2d(256, 256, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(256),
    nn.ReLU(True),

    nn.Upsample(scale_factor=2),
    nn.Conv2d(256, 128, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    nn.Conv2d(128, 128, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(True),

    nn.Upsample(scale_factor=2),
    nn.Conv2d(128, 64, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    nn.Conv2d(64, 64, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(True),

    nn.Upsample(scale_factor=2),
    nn.Conv2d(64, 32, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(True),
    nn.Conv2d(32, 32, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(True),

    nn.Upsample(scale_factor=2),
    nn.Conv2d(32, 1, (3, 3), bias=False, padding=1),
    nn.BatchNorm2d(1),
    nn.ReLU(True),
    nn.Conv2d(1, 1, (3, 3), bias=False, padding=1)
)

# %%
encoder = encoder(config['latent_dim'])
decoder = decoder(config['latent_dim'])

model = nn.Sequential(
    encoder,
    decoder
).to(config['device'])

# %%
optimizer = torch.optim.AdamW(model.parameters(), weight_decay=0, lr=config["learning_rate"], betas=(0.8, 0.999))
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lambda epoch : (1-config["learning_rate_decay"])**epoch)
MSE = torch.nn.MSELoss()
train_loader = DataLoader(music_ads['train'], batch_size=8, num_workers=8, shuffle=True, pin_memory=True, pin_memory_device=config['device'])

# %%
step, loss = 0, []

for epoch in range(1):
    for data in tqdm(train_loader, desc=str(epoch), leave=False):
        # prevtime = datetime.now()

        x = data['audio']
        
        optimizer.zero_grad()
        label = x.to(config["device"])[..., :256]
        
        x = encoder(label)
        
        pred = decoder(x)


        score = MSE(label, pred)
        score.backward()
        optimizer.step()
        
        loss.append(score.item())
        # print(datetime.now())

        if len(loss) > 2000 and np.median(loss[-2000:-1000]) < np.median(loss[-1000:]):
            print('Early stop')
            torch.save(model.state_dict(), "model.pt")
            exit()

        step += 1

        if step % 500 == 0: # scheduler
            scheduler.step()
            
            print(score)

        # # Plot images
        # if step % 100 == 0 :
        #     # Plot reconstructions
        #     images = [(e-e.min())/(e.max()-e.min()) for e in label[:8]]
        #     grid = make_grid(images)
            
            
        #     images = [(e-e.min())/(e.max()-e.min()) for e in pred[:8]]
        #     grid = make_grid(images)
# Out:
# 0:   0%|          | 0/635 [00:00<?, ?it/s]
# tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
torch.save(model.state_dict(), "dim_10_muha.pt")

# %%
model.load_state_dict(torch.load('dim_10_muha.pt'))
# Out:
# <All keys matched successfully>

# %%
music_ads['test'].set_transform(preprocessor)
test_loader = DataLoader(music_ads['test'], batch_size=8, num_workers=12, shuffle=True, pin_memory=True, pin_memory_device=config['device'])


test_losses = []

test_embeddings = []


for data in tqdm(test_loader):
    x = data['audio']
    with torch.no_grad():
        label = x.to(config["device"])[..., :256]
        
        x = encoder(label)
        
        test_embeddings.append(x.detach().cpu())
        
        pred = decoder(x)


        score = MSE(label, pred)
    
        test_losses.append(score.item())
# Out:
#   0%|          | 0/191 [00:00<?, ?it/s]

# %%
plotting_data = np.concat(test_embeddings, axis=0).squeeze()

# %%
np.array(test_losses).mean()
# Out:
# np.float64(0.003400773553291844)

# %%
normalize = lambda e: (e-e.min())/(e.max()-e.min())

# %%
import matplotlib.pyplot as plt

plt.imshow(normalize(label[1]).detach().cpu().squeeze())

# %%
plt.imshow(normalize(pred[1]).detach().cpu().squeeze())
